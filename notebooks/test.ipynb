# %%
from utils import *

# %%
img_dir = '../assets/images/'

# %%
img = cv2.imread(img_dir+'opencv.jpg')
plott(img)

# %%
cntrs, hierarchy = findContours(img, retr='tree')
plott(drawContours(img, cntrs, -1))

# %%
cntrs = sort_cntrs(cntrs)

# %%
plott(drawContours(img, cntrs, 0))

# %%
hierarchy
# Out:
# array([[[ 1, -1, -1, -1],
#         [ 3,  0,  2, -1],
#         [-1, -1, -1,  1],
#         [ 5,  1,  4, -1],
#         [-1, -1, -1,  3],
#         [ 6,  3, -1, -1],
#         [ 7,  5, -1, -1],
#         [-1,  6,  8, -1],
#         [-1, -1, -1,  7]]], dtype=int32)
