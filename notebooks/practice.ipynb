# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
from typing import Optional, Tuple

# %%
def plott(
    img1: np.ndarray,
    img2: Optional[np.ndarray] = None,
    title1: str = "",
    title2: str = "",
    scale: float = 1
) -> None:

    # img1 only
    if img2 is None:
        plt.figure(figsize=(10*scale, 10*scale))
        if len(img1.shape) == 3:
            plt.imshow(img1[:, :, ::-1])
            plt.title(title1)
        else:
            plt.imshow(img1, cmap="gray")
            plt.title(title1)

    # img1 & img2 both
    else:
        plt.figure(figsize=(20*scale, 20*scale))
        if len(img1.shape) == 3:
            plt.subplot(121)
            plt.imshow(img1[:, :, ::-1])
            plt.title(title1)
        else:
            plt.subplot(121)
            plt.imshow(img1, cmap="gray")
            plt.title(title1)
        if len(img2.shape) == 3:
            plt.subplot(122)
            plt.imshow(img2[:, :, ::-1])
            plt.title(title2)
        else:
            plt.subplot(122)
            plt.imshow(img2, cmap="gray")
            plt.title(title2)

# %%
Mat = np.ndarray
img: Mat = cv2.imread('linus.jpg')
gray: Mat = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
blank: Mat = np.zeros(img.shape[:2], np.uint8)
mask: Mat = cv2.circle(blank, (img.shape[1]//2, img.shape[0]//2), 200, 255, -1)
colors: Tuple[str, str, str] = ('b', 'g', 'r')
plt.title('Grayscale Histogram')
plt.xlabel('Bins')
plt.ylabel('# of pixels')
i: int; col: str
for i, col in enumerate(colors):
    hist = cv2.calcHist([img], [i], None, [256], [0, 256])
    plt.plot(hist, color=col)
    plt.xlim([0, 256])
# Out:
# (0.0, 256.0)

# %%
plott(cv2.bitwise_and(gray, gray, mask=mask))

# %%
img = np.ones((0, 5), np.uint8)
for i in range(5):
    img = np.append(img, np.random.randint(0, 255, (1, 5)), axis=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2704/401550543.py in <module>
# ----> 1 img = np.ones((0, 5), np.uint8)
#       2 for i in range(5):
#       3     img = np.append(img, np.random.randint(0, 255, (1, 5)), axis=0)
#
# NameError: name 'np' is not defined
